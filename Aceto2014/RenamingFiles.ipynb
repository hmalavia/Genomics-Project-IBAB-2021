# %%
import numpy as np
import pandas as pd
import os

# %%
pd.options.mode.chained_assignment=None

# %%
import pandas as pd
import os

df=pd.read_csv('SraRunTable.csv')
df.head(10)


dfFilt=df[['Run','patient','also_known_as','single_cells_or_cluster']]

dfFilt

dfFilt['filename']=dfFilt['patient']+dfFilt['single_cells_or_cluster']

c=dfFilt.groupby('filename').cumcount()+1

dfFilt['c']=c

dfFilt['newfilename']=dfFilt['filename'] + dfFilt['c'].astype('str')

ogfilename=dfFilt['Run']+'.fastq'
newfilename=dfFilt['newfilename']+'.fastq'

d=dict(zip(ogfilename,newfilename))
d

for a,b,c in os.walk('/home/ibab/Documents/python/renaming/'):
    os.chdir(a)
    cwd=a
    l=os.listdir(cwd)
    for i in l:
        base=a
        src=base+'/'+i
        if i in d.keys():
            dst=d[i]
            os.rename(src,dst)
        
    os.chdir('../')
# Out:
# /tmp/ipykernel_136883/1539874971.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfFilt['filename']=dfFilt['patient']+dfFilt['single_cells_or_cluster']
# /tmp/ipykernel_136883/1539874971.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfFilt['c']=c
# /tmp/ipykernel_136883/1539874971.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfFilt['newfilename']=dfFilt['filename'] + dfFilt['c'].astype('str')
# {'SRR1020057.fastq': 'Patient#1CL1.fastq',
#  'SRR1020058.fastq': 'Patient#1CL2.fastq',
#  'SRR1020059.fastq': 'Patient#1CL3.fastq',
#  'SRR1020060.fastq': 'Patient#1CL4.fastq',
#  'SRR1020061.fastq': 'Patient#1CL5.fastq',
#  'SRR1020062.fastq': 'Patient#1CL6.fastq',
#  'SRR1020063.fastq': 'Patient#1SC1.fastq',
#  'SRR1020064.fastq': 'Patient#1SC2.fastq',
#  'SRR1020065.fastq': 'Patient#1SC3.fastq',
#  'SRR1020066.fastq': 'Patient#1SC4.fastq',
#  'SRR1020067.fastq': 'Patient#1SC5.fastq',
#  'SRR1020068.fastq': 'Patient#1SC6.fastq',
#  'SRR1020069.fastq': 'Patient#2SC1.fastq',
#  'SRR1020070.fastq': 'Patient#2SC2.fastq',
#  'SRR1020071.fastq': 'Patient#2SC3.fastq',
#  'SRR1020072.fastq': 'Patient#2SC4.fastq',
#  'SRR1020073.fastq': 'Patient#2SC5.fastq',
#  'SRR1020074.fastq': 'Patient#2SC6.fastq',
#  'SRR1020075.fastq': 'Patient#3SC1.fastq',
#  'SRR1020076.fastq': 'Patient#3SC2.fastq',
#  'SRR1020077.fastq': 'Patient#3SC3.fastq',
#  'SRR1020078.fastq': 'Patient#3SC4.fastq',
#  'SRR1020079.fastq': 'Patient#3SC5.fastq',
#  'SRR1020080.fastq': 'Patient#3SC6.fastq',
#  'SRR1020081.fastq': 'Patient#4SC1.fastq',
#  'SRR1020082.fastq': 'Patient#4SC2.fastq',
#  'SRR1020083.fastq': 'Patient#4SC3.fastq',
#  'SRR1020084.fastq': 'Patient#4SC4.fastq',
#  'SRR1020085.fastq': 'Patient#4SC5.fastq',
#  'SRR1020086.fastq': 'Patient#4SC6.fastq',
#  'SRR1020087.fastq': 'Patient#5SC1.fastq',
#  'SRR1020088.fastq': 'Patient#5SC2.fastq',
#  'SRR1020089.fastq': 'Patient#5SC3.fastq',
#  'SRR1020090.fastq': 'Patient#5SC4.fastq',
#  'SRR1020091.fastq': 'Patient#5SC5.fastq',
#  'SRR1020092.fastq': 'Patient#5SC6.fastq',
#  'SRR1020093.fastq': 'Patient#2CL1.fastq',
#  'SRR1020094.fastq': 'Patient#2CL2.fastq',
#  'SRR1020095.fastq': 'Patient#2CL3.fastq',
#  'SRR1020096.fastq': 'Patient#2CL4.fastq',
#  'SRR1020097.fastq': 'Patient#2CL5.fastq',
#  'SRR1020098.fastq': 'Patient#2CL6.fastq',
#  'SRR1020099.fastq': 'Patient#5SC7.fastq',
#  'SRR1020100.fastq': 'Patient#5SC8.fastq',
#  'SRR1020101.fastq': 'Patient#5SC9.fastq',
#  'SRR1020102.fastq': 'Patient#5SC10.fastq',
#  'SRR1020103.fastq': 'Patient#5SC11.fastq',
#  'SRR1020104.fastq': 'Patient#5SC12.fastq',
#  'SRR1020105.fastq': 'Patient#6CL1.fastq',
#  'SRR1020106.fastq': 'Patient#6CL2.fastq',
#  'SRR1020107.fastq': 'Patient#6CL3.fastq',
#  'SRR1020108.fastq': 'Patient#6CL4.fastq',
#  'SRR1020109.fastq': 'Patient#6CL5.fastq',
#  'SRR1020110.fastq': 'Patient#6CL6.fastq',
#  'SRR1020111.fastq': 'Patient#6SC1.fastq',
#  'SRR1020112.fastq': 'Patient#6SC2.fastq',
#  'SRR1020113.fastq': 'Patient#6SC3.fastq',
#  'SRR1020114.fastq': 'Patient#6SC4.fastq',
#  'SRR1020115.fastq': 'Patient#6SC5.fastq',
#  'SRR1020116.fastq': 'Patient#6SC6.fastq',
#  'SRR1020117.fastq': 'Patient#7CL1.fastq',
#  'SRR1020118.fastq': 'Patient#7CL2.fastq',
#  'SRR1020119.fastq': 'Patient#7CL3.fastq',
#  'SRR1020120.fastq': 'Patient#7CL4.fastq',
#  'SRR1020121.fastq': 'Patient#7CL5.fastq',
#  'SRR1020122.fastq': 'Patient#7CL6.fastq',
#  'SRR1020123.fastq': 'Patient#7SC1.fastq',
#  'SRR1020124.fastq': 'Patient#7SC2.fastq',
#  'SRR1020125.fastq': 'Patient#7SC3.fastq',
#  'SRR1020126.fastq': 'Patient#7SC4.fastq',
#  'SRR1020127.fastq': 'Patient#7SC5.fastq',
#  'SRR1020128.fastq': 'Patient#7SC6.fastq',
#  'SRR1020129.fastq': 'Patient#8SC1.fastq',
#  'SRR1020130.fastq': 'Patient#8SC2.fastq',
#  'SRR1020131.fastq': 'Patient#8SC3.fastq',
#  'SRR1020132.fastq': 'Patient#8SC4.fastq',
#  'SRR1020133.fastq': 'Patient#8SC5.fastq',
#  'SRR1020134.fastq': 'Patient#8SC6.fastq',
#  'SRR1020135.fastq': 'Patient#9CL1.fastq',
#  'SRR1020136.fastq': 'Patient#9CL2.fastq',
#  'SRR1020137.fastq': 'Patient#9CL3.fastq',
#  'SRR1020138.fastq': 'Patient#9CL4.fastq',
#  'SRR1020139.fastq': 'Patient#9CL5.fastq',
#  'SRR1020140.fastq': 'Patient#9CL6.fastq',
#  'SRR1020141.fastq': 'Patient#9SC1.fastq',
#  'SRR1020142.fastq': 'Patient#9SC2.fastq',
#  'SRR1020143.fastq': 'Patient#9SC3.fastq',
#  'SRR1020144.fastq': 'Patient#9SC4.fastq',
#  'SRR1020145.fastq': 'Patient#9SC5.fastq',
#  'SRR1020146.fastq': 'Patient#9SC6.fastq',
#  'SRR1020147.fastq': 'Patient#7SC7.fastq',
#  'SRR1020148.fastq': 'Patient#7SC8.fastq',
#  'SRR1020149.fastq': 'Patient#7SC9.fastq',
#  'SRR1020150.fastq': 'Patient#7SC10.fastq',
#  'SRR1020151.fastq': 'Patient#7SC11.fastq',
#  'SRR1020152.fastq': 'Patient#7SC12.fastq',
#  'SRR1020153.fastq': 'Patient#5CL1.fastq',
#  'SRR1020154.fastq': 'Patient#5CL2.fastq',
#  'SRR1020155.fastq': 'Patient#5CL3.fastq',
#  'SRR1020156.fastq': 'Patient#5CL4.fastq',
#  'SRR1020157.fastq': 'Patient#5CL5.fastq',
#  'SRR1020158.fastq': 'Patient#4SC7.fastq',
#  'SRR1020159.fastq': 'Patient#4SC8.fastq',
#  'SRR1020160.fastq': 'Patient#4SC9.fastq',
#  'SRR1020161.fastq': 'Patient#4SC10.fastq',
#  'SRR1020162.fastq': 'Patient#4SC11.fastq',
#  'SRR1020163.fastq': 'Patient#4SC12.fastq',
#  'SRR1020164.fastq': 'Patient#4CL1.fastq',
#  'SRR1020165.fastq': 'Patient#4CL2.fastq',
#  'SRR1020166.fastq': 'Patient#4CL3.fastq',
#  'SRR1020167.fastq': 'Patient#4CL4.fastq',
#  'SRR1020168.fastq': 'Patient#4CL5.fastq',
#  'SRR1020169.fastq': 'Patient#4CL6.fastq',
#  'SRR1020170.fastq': 'Patient#4CL7.fastq',
#  'SRR1020171.fastq': 'Patient#4CL8.fastq',
#  'SRR1020172.fastq': 'Patient#4CL9.fastq',
#  'SRR1020173.fastq': 'Patient#4CL10.fastq',
#  'SRR1020174.fastq': 'Patient#4CL11.fastq',
#  'SRR1020175.fastq': 'Patient#4CL12.fastq',
#  'SRR1020176.fastq': 'Patient#4CL13.fastq',
#  'SRR1020177.fastq': 'Patient#4CL14.fastq',
#  'SRR1020178.fastq': 'Patient#4CL15.fastq',
#  'SRR1020179.fastq': 'Patient#4CL16.fastq',
#  'SRR1020180.fastq': 'Patient#4CL17.fastq',
#  'SRR1020181.fastq': 'Patient#4CL18.fastq',
#  'SRR1020182.fastq': 'Patient#3CL1.fastq',
#  'SRR1020183.fastq': 'Patient#3CL2.fastq',
#  'SRR1020184.fastq': 'Patient#3CL3.fastq',
#  'SRR1020185.fastq': 'Patient#3CL4.fastq',
#  'SRR1020186.fastq': 'Patient#3CL5.fastq',
#  'SRR1020187.fastq': 'Patient#3CL6.fastq',
#  'SRR1020188.fastq': 'Patient#10SC1.fastq',
#  'SRR1020189.fastq': 'Patient#10SC2.fastq',
#  'SRR1020190.fastq': 'Patient#10SC3.fastq',
#  'SRR1020191.fastq': 'Patient#10SC4.fastq',
#  'SRR1020192.fastq': 'Patient#10SC5.fastq',
#  'SRR1020193.fastq': 'Patient#10CL1.fastq',
#  'SRR1020194.fastq': 'Patient#10CL2.fastq',
#  'SRR1020195.fastq': 'Patient#10CL3.fastq',
#  'SRR1020196.fastq': 'Patient#10CL4.fastq',
#  'SRR1020197.fastq': 'Patient#10CL5.fastq',
#  'SRR1020198.fastq': 'Patient#10CL6.fastq',
#  'SRR1020199.fastq': 'Patient#10CL7.fastq',
#  'SRR1020200.fastq': 'Patient#10CL8.fastq',
#  'SRR1020201.fastq': 'Patient#10CL9.fastq',
#  'SRR1020202.fastq': 'Patient#10CL10.fastq',
#  'SRR1020203.fastq': 'Patient#10CL11.fastq',
#  'SRR1020204.fastq': 'Patient#10CL12.fastq',
#  'SRR1020205.fastq': 'Patient#8CL1.fastq',
#  'SRR1020206.fastq': 'Patient#8CL2.fastq',
#  'SRR1020207.fastq': 'Patient#8CL3.fastq',
#  'SRR1020208.fastq': 'Patient#8CL4.fastq',
#  'SRR1020209.fastq': 'Patient#8CL5.fastq',
#  'SRR1020210.fastq': 'Patient#8CL6.fastq',
#  'SRR1020211.fastq': 'Patient#8CL7.fastq',
#  'SRR1020212.fastq': 'Patient#8CL8.fastq',
#  'SRR1020213.fastq': 'Patient#8CL9.fastq',
#  'SRR1020214.fastq': 'Patient#8CL10.fastq',
#  'SRR1020215.fastq': 'Patient#8CL11.fastq',
#  'SRR1020216.fastq': 'Patient#8CL12.fastq',
#  'SRR1020217.fastq': 'Patient#8SC7.fastq',
#  'SRR1020218.fastq': 'Patient#8SC8.fastq',
#  'SRR1020219.fastq': 'Patient#8SC9.fastq',
#  'SRR1020220.fastq': 'Patient#8SC10.fastq',
#  'SRR1020221.fastq': 'Patient#8SC11.fastq',
#  'SRR1020222.fastq': 'Patient#8SC12.fastq',
#  'SRR1020223.fastq': 'Patient#8SC13.fastq',
#  'SRR1020224.fastq': 'Patient#8SC14.fastq',
#  'SRR1020225.fastq': 'Patient#8SC15.fastq',
#  'SRR1020226.fastq': 'Patient#8SC16.fastq',
#  'SRR1020227.fastq': 'Patient#8SC17.fastq',
#  'SRR1020228.fastq': 'Patient#8SC18.fastq'}
